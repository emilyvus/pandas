# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon_data.csv")

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.shape
# Out:
# (800, 12)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
df.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df1 = pd.read_csv("pokemon_data.txt",sep='\t')

# %%
df1.shape
# Out:
# (800, 12)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df ["Name"]
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df[['Name','HP']]
# Out:
#                       Name  HP
# 0                Bulbasaur  45
# 1                  Ivysaur  60
# 2                 Venusaur  80
# 3    VenusaurMega Venusaur  80
# 4               Charmander  39
# ..                     ...  ..
# 795                Diancie  50
# 796    DiancieMega Diancie  50
# 797    HoopaHoopa Confined  80
# 798     HoopaHoopa Unbound  80
# 799              Volcanion  80
#
# [800 rows x 2 columns]

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df['Name'][0:5]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df[['Name','Type 1', 'HP']]
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
df.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.iloc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
df.iloc[2,1]
# Out:
# 'Venusaur'

# %%
for index,row in df.iterrows():
    print(index)
    print ("----------------------")
    print (row)
    print ("----------------------")
    print("Listing row content")
    print (row["Name"])
    break
# Out:
# 0
# ----------------------
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# ----------------------
# Listing row content
# Bulbasaur

# %%
df.loc[df['Type 1'] == "Grass"].shape
# Out:
# (70, 12)

# %%
df.loc[(df['Type 1'] == "Fire") & (df['Name'] == "Ponyta")]
# Out:
#      #    Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 83  77  Ponyta   Fire    NaN  50      85       55       65       65     90
#
#     Generation  Legendary
# 83           1      False

# %%
df.loc[(df['Type 1'] == "Fire") | (df['Name'] == "Ponyta")].shape
# Out:
# (52, 12)

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(by=['Name'])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(by=['Type 1','Name'])
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 678  617               Accelgor    Bug     NaN   80      70       40      100
# 182  168                Ariados    Bug  Poison   70      90       70       60
# 290  267              Beautifly    Bug  Flying   60      70       50      100
# 18    15               Beedrill    Bug  Poison   65      90       40       45
# 19    15  BeedrillMega Beedrill    Bug  Poison   65     150       40       15
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 351  321                Wailord  Water     NaN  170      90       45       90
# 10     8              Wartortle  Water     NaN   59      63       80       65
# 372  340               Whiscash  Water  Ground  110      78       73       76
# 301  278                Wingull  Water  Flying   40      30       30       55
# 209  194                 Wooper  Water  Ground   55      45       45       25
#
# ...

# %%
df.sort_values(by=['Type 1','Name'],ascending=[0,1])
# Out:
#        #                 Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 655  594            Alomomola  Water     NaN  165      75       80       40
# 199  184            Azumarill  Water   Fairy  100      50       80       60
# 371  339             Barboach  Water  Ground   50      48       43       46
# 610  550             Basculin  Water     NaN   70      92       65       80
# 11     9            Blastoise  Water     NaN   79      83      100       85
# ..   ...                  ...    ...     ...  ...     ...      ...      ...
# 459  413  WormadamSandy Cloak    Bug  Ground   60      79      105       59
# 460  413  WormadamTrash Cloak    Bug   Steel   60      69       95       69
# 288  265              Wurmple    Bug     NaN   45      45       35       20
# 208  193                Yanma    Bug  Flying   65      65       45       75
# 520  469              Yanmega    Bug  Flying   86      76       86      116
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making changes to Data

# %% [markdown]
# ## This is a good place for you to take notes so later you can refer to it

# %% [markdown]
# ### Level 3 heading

# %%
df.head (5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
45+49+49+65+65+45
# Out:
# 318

# %%
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

df = df.drop(columns=['Total'])

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

#df = df.drop(columns=['Total'])

df['Total'] = df.iloc[:,4:10].sum(axis=1)



df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
cols = list(df.columns)

# %%
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
l =['#',
 'Name',
 'Type 1',
 'Type 2',
 'HP',
 'Attack',
 'Total',
 'Defense',
 'Sp. Atk',
 'Sp. Def',
 'Speed',
 'Generation',
 'Legendary']

# %%
df=df[l]

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Total  Defense  \
# 0  1              Bulbasaur  Grass  Poison  45      49    318       49
# 1  2                Ivysaur  Grass  Poison  60      62    405       63
# 2  3               Venusaur  Grass  Poison  80      82    525       83
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100    625      123
# 4  4             Charmander   Fire     NaN  39      52    309       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# # Saving Data

# %%
#df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# # Filtering Data

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Total  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49    318       49
# 1      2                Ivysaur  Grass    Poison   60      62    405       63
# 2      3               Venusaur  Grass    Poison   80      82    525       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100    625      123
# 48    43                 Oddish  Grass    Poison   45      50    320       55
# ..   ...                    ...    ...       ...  ...     ...    ...      ...
# 718  650                Chespin  Grass       NaN   56      61    313       65
# 719  651              Quilladin  Grass       NaN   61      78    405       95
# 720  652             Chesnaught  Grass  Fighting   88     107    530      122
# 740  672                 Skiddo  Grass       NaN   66      65    350       48
# 741  673                 Gogoat  Grass       NaN  123     100    531       62
#
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Total  Defense  \
# 0      1              Bulbasaur  Grass  Poison   45      49    318       49
# 1      2                Ivysaur  Grass  Poison   60      62    405       63
# 2      3               Venusaur  Grass  Poison   80      82    525       83
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100    625      123
# 48    43                 Oddish  Grass  Poison   45      50    320       55
# 49    44                  Gloom  Grass  Poison   60      65    395       70
# 50    45              Vileplume  Grass  Poison   75      80    490       85
# 75    69             Bellsprout  Grass  Poison   50      75    300       35
# 76    70             Weepinbell  Grass  Poison   65      90    390       50
# 77    71             Victreebel  Grass  Poison   80     105    490       65
# 344  315                Roselia  Grass  Poison   50      60    400       45
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Total  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49    318       49
# 1      2                Ivysaur  Grass    Poison   60      62    405       63
# 2      3               Venusaur  Grass    Poison   80      82    525       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100    625      123
# 16    13                 Weedle    Bug    Poison   40      35    195       30
# ..   ...                    ...    ...       ...  ...     ...    ...      ...
# 718  650                Chespin  Grass       NaN   56      61    313       65
# 719  651              Quilladin  Grass       NaN   61      78    405       95
# 720  652             Chesnaught  Grass  Fighting   88     107    530      122
# 740  672                 Skiddo  Grass       NaN   66      65    350       48
# 741  673                 Gogoat  Grass       NaN  123     100    531       62
#
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Total  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49    318       49
# 1      2                Ivysaur  Grass    Poison   60      62    405       63
# 2      3               Venusaur  Grass    Poison   80      82    525       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100    625      123
# 48    43                 Oddish  Grass    Poison   45      50    320       55
# ..   ...                    ...    ...       ...  ...     ...    ...      ...
# 718  650                Chespin  Grass       NaN   56      61    313       65
# 719  651              Quilladin  Grass       NaN   61      78    405       95
# 720  652             Chesnaught  Grass  Fighting   88     107    530      122
# 740  672                 Skiddo  Grass       NaN   66      65    350       48
# 741  673                 Gogoat  Grass       NaN  123     100    531       62
#
# ...

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

new_df.to_csv('filtered.csv')

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

#new_df.to_csv('filtered.csv')

new_df.reset_index(drop=True, inplace=True)

new_df
# Out:
#       #                   Name Type 1    Type 2   HP  Attack  Total  Defense  \
# 0     1              Bulbasaur  Grass    Poison   45      49    318       49
# 1     2                Ivysaur  Grass    Poison   60      62    405       63
# 2     3               Venusaur  Grass    Poison   80      82    525       83
# 3     3  VenusaurMega Venusaur  Grass    Poison   80     100    625      123
# 4    43                 Oddish  Grass    Poison   45      50    320       55
# ..  ...                    ...    ...       ...  ...     ...    ...      ...
# 66  650                Chespin  Grass       NaN   56      61    313       65
# 67  651              Quilladin  Grass       NaN   61      78    405       95
# 68  652             Chesnaught  Grass  Fighting   88     107    530      122
# 69  672                 Skiddo  Grass       NaN   66      65    350       48
# 70  673                 Gogoat  Grass       NaN  123     100    531       62
#
# ...

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Total  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100    625
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130    634
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104    634
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103    630
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150    495
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80    579
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50    590
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75    590
# 102   94          GengarMega Gengar     Ghost    Poison   60      65    600
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125    590
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155    600
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Total  Defense  \
# 0      1            Bulbasaur    Grass  Poison   45      49    318       49
# 1      2              Ivysaur    Grass  Poison   60      62    405       63
# 2      3             Venusaur    Grass  Poison   80      82    525       83
# 4      4           Charmander     Fire     NaN   39      52    309       43
# 5      5           Charmeleon     Fire     NaN   58      64    405       58
# ..   ...                  ...      ...     ...  ...     ...    ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100    600      121
# 795  719              Diancie     Rock   Fairy   50     100    600      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110    600       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160    680       60
# 799  721            Volcanion     Fire   Water   80     110    600      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Total  Defense  \
# 0      1              Bulbasaur  Grass  Poison   45      49    318       49
# 1      2                Ivysaur  Grass  Poison   60      62    405       63
# 2      3               Venusaur  Grass  Poison   80      82    525       83
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100    625      123
# 4      4             Charmander   Fire     NaN   39      52    309       43
# ..   ...                    ...    ...     ...  ...     ...    ...      ...
# 735  667                 Litleo   Fire  Normal   62      50    369       58
# 736  668                 Pyroar   Fire  Normal   86      68    507       72
# 740  672                 Skiddo  Grass     NaN   66      65    350       48
# 741  673                 Gogoat  Grass     NaN  123     100    531       62
# 799  721              Volcanion   Fire   Water   80     110    600      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Total  Defense  \
# 0      1              Bulbasaur  Grass  Poison   45      49    318       49
# 1      2                Ivysaur  Grass  Poison   60      62    405       63
# 2      3               Venusaur  Grass  Poison   80      82    525       83
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100    625      123
# 4      4             Charmander   Fire     NaN   39      52    309       43
# ..   ...                    ...    ...     ...  ...     ...    ...      ...
# 735  667                 Litleo   Fire  Normal   62      50    369       58
# 736  668                 Pyroar   Fire  Normal   86      68    507       72
# 740  672                 Skiddo  Grass     NaN   66      65    350       48
# 741  673                 Gogoat  Grass     NaN  123     100    531       62
# 799  721              Volcanion   Fire   Water   80     110    600      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Total  \
# 20    16               Pidgey    Normal    Flying   40      45    251
# 21    17            Pidgeotto    Normal    Flying   63      60    349
# 22    18              Pidgeot    Normal    Flying   83      80    479
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80    579
# 30    25              Pikachu  Electric       NaN   35      55    320
# 136  127               Pinsir       Bug       NaN   65     125    500
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155    600
# 186  172                Pichu  Electric       NaN   20      40    205
# 219  204               Pineco       Bug       NaN   50      65    290
# 239  221            Piloswine       Ice    Ground  100     100    450
# 438  393               Piplup     Water       NaN   53      51    314
# 558  499              Pignite      Fire  Fighting   90      93    418
# ...

# %% [markdown]
# # Conditional Changes

# %%
df.loc[df['Type 1']=='Fire', 'Type 1'] = 'Flamer'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Total  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49    318       49
# 1      2                Ivysaur    Grass  Poison  60      62    405       63
# 2      3               Venusaur    Grass  Poison  80      82    525       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100    625      123
# 4      4             Charmander   Flamer     NaN  39      52    309       43
# ..   ...                    ...      ...     ...  ..     ...    ...      ...
# 795  719                Diancie     Rock   Fairy  50     100    600      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160    700      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110    600       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160    680       60
# 799  721              Volcanion   Flamer   Water  80     110    600      120
#
# ...

# %%
df.loc[df['Type 1']=='Flamer', 'Type 1'] = 'Fire'

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Total  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49    318       49
# 1      2                Ivysaur    Grass  Poison  60      62    405       63
# 2      3               Venusaur    Grass  Poison  80      82    525       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100    625      123
# 4      4             Charmander     Fire     NaN  39      52    309       43
# ..   ...                    ...      ...     ...  ..     ...    ...      ...
# 795  719                Diancie     Rock   Fairy  50     100    600      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160    700      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110    600       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160    680       60
# 799  721              Volcanion     Fire   Water  80     110    600      120
#
# ...

# %%
df.loc[df['Type 1']=='Fire', 'Legendary'] = True

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Total  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49    318       49
# 1      2                Ivysaur    Grass  Poison  60      62    405       63
# 2      3               Venusaur    Grass  Poison  80      82    525       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100    625      123
# 4      4             Charmander     Fire     NaN  39      52    309       43
# ..   ...                    ...      ...     ...  ..     ...    ...      ...
# 795  719                Diancie     Rock   Fairy  50     100    600      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160    700      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110    600       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160    680       60
# 799  721              Volcanion     Fire   Water  80     110    600      120
#
# ...

# %%
df=pd.read_csv('modified.csv')

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Total  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49    318       49
# 1      2                Ivysaur    Grass  Poison  60      62    405       63
# 2      3               Venusaur    Grass  Poison  80      82    525       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100    625      123
# 4      4             Charmander     Fire     NaN  39      52    309       43
# ..   ...                    ...      ...     ...  ..     ...    ...      ...
# 795  719                Diancie     Rock   Fairy  50     100    600      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160    700      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110    600       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160    680       60
# 799  721              Volcanion     Fire   Water  80     110    600      120
#
# ...

# %%
df.loc[df['Total'] > 500,['Generation', 'Legendary']] = 'TEST VALUE'

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Total  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49    318       49
# 1      2                Ivysaur    Grass  Poison  60      62    405       63
# 2      3               Venusaur    Grass  Poison  80      82    525       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100    625      123
# 4      4             Charmander     Fire     NaN  39      52    309       43
# ..   ...                    ...      ...     ...  ..     ...    ...      ...
# 795  719                Diancie     Rock   Fairy  50     100    600      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160    700      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110    600       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160    680       60
# 799  721              Volcanion     Fire   Water  80     110    600      120
#
# ...

# %%
df.loc[df['Total'] > 500,['Generation', 'Legendary']] = ['Test 1', 'Test 2']

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Total  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49    318       49
# 1      2                Ivysaur    Grass  Poison  60      62    405       63
# 2      3               Venusaur    Grass  Poison  80      82    525       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100    625      123
# 4      4             Charmander     Fire     NaN  39      52    309       43
# ..   ...                    ...      ...     ...  ..     ...    ...      ...
# 795  719                Diancie     Rock   Fairy  50     100    600      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160    700      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110    600       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160    680       60
# 799  721              Volcanion     Fire   Water  80     110    600      120
#
# ...

# %%
#df.loc[df['Total'] > 500,['Generation', 'Legendary']] = ['Test 1', 'Test 2']

#df

df = pd.read_csv('modified.csv')

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Total  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49    318       49
# 1      2                Ivysaur    Grass  Poison  60      62    405       63
# 2      3               Venusaur    Grass  Poison  80      82    525       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100    625      123
# 4      4             Charmander     Fire     NaN  39      52    309       43
# ..   ...                    ...      ...     ...  ..     ...    ...      ...
# 795  719                Diancie     Rock   Fairy  50     100    600      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160    700      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110    600       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160    680       60
# 799  721              Volcanion     Fire   Water  80     110    600      120
#
# ...

# %% [markdown]
# # Aggregate Statistics

# %%
df = pd.read_csv('modified.csv')

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Total  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49    318       49
# 1      2                Ivysaur    Grass  Poison  60      62    405       63
# 2      3               Venusaur    Grass  Poison  80      82    525       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100    625      123
# 4      4             Charmander     Fire     NaN  39      52    309       43
# ..   ...                    ...      ...     ...  ..     ...    ...      ...
# 795  719                Diancie     Rock   Fairy  50     100    600      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160    700      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110    600       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160    680       60
# 799  721              Volcanion     Fire   Water  80     110    600      120
#
# ...

# %%
df[['Type 1','Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].groupby(['Type 1']).mean()
# Out:
#                Total         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       378.927536  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      445.741935  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    550.531250  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  443.409091  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     413.176471  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  416.444444  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      458.076923  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    485.000000  70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost     439.562500  64.437500   73.781250   81.187500  79.343750  76.468750
# Grass     421.142857  67.271429   73.214286   70.800000  77.500000  70.428571
# Ground    437.500000  73.781250   95.750000   84.843750  56.468750  62.750000
# ...

# %%
df[['Type 1','Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                Total         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    550.531250  83.312500  112.125000   86.375000  96.843750  88.843750
# Fighting  416.444444  69.851852   96.777778   65.925926  53.111111  64.703704
# Ground    437.500000  73.781250   95.750000   84.843750  56.468750  62.750000
# Rock      453.750000  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     487.703704  65.222222   92.703704  126.370370  67.518519  80.629630
# Dark      445.741935  66.806452   88.387097   70.225806  74.645161  69.516129
# Fire      458.076923  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    485.000000  70.750000   78.750000   66.250000  94.250000  72.500000
# Poison    399.142857  67.250000   74.678571   68.821429  60.428571  64.392857
# Water     430.455357  72.062500   74.151786   72.946429  74.812500  70.517857
# Ghost     439.562500  64.437500   73.781250   81.187500  79.343750  76.468750
# ...

# %%
df[['Type 1','Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].groupby(['Type 1']).mean().sort_values('Attack', ascending=False)
# Out:
#                Total         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    550.531250  83.312500  112.125000   86.375000  96.843750  88.843750
# Fighting  416.444444  69.851852   96.777778   65.925926  53.111111  64.703704
# Ground    437.500000  73.781250   95.750000   84.843750  56.468750  62.750000
# Rock      453.750000  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     487.703704  65.222222   92.703704  126.370370  67.518519  80.629630
# Dark      445.741935  66.806452   88.387097   70.225806  74.645161  69.516129
# Fire      458.076923  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    485.000000  70.750000   78.750000   66.250000  94.250000  72.500000
# Poison    399.142857  67.250000   74.678571   68.821429  60.428571  64.392857
# Water     430.455357  72.062500   74.151786   72.946429  74.812500  70.517857
# Ghost     439.562500  64.437500   73.781250   81.187500  79.343750  76.468750
# ...

# %%
df[['Type 1','Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].groupby(['Type 1']).mean().sort_values('HP', ascending=False)
# Out:
#                Total         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    550.531250  83.312500  112.125000   86.375000  96.843750  88.843750
# Normal    401.683673  77.275510   73.469388   59.846939  55.816327  63.724490
# Fairy     413.176471  74.117647   61.529412   65.705882  78.529412  84.705882
# Ground    437.500000  73.781250   95.750000   84.843750  56.468750  62.750000
# Water     430.455357  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       433.458333  72.000000   72.750000   71.416667  77.541667  76.291667
# Flying    485.000000  70.750000   78.750000   66.250000  94.250000  72.500000
# Psychic   475.947368  70.631579   71.456140   67.684211  98.403509  86.280702
# Fire      458.076923  69.903846   84.769231   67.769231  88.980769  72.211538
# Fighting  416.444444  69.851852   96.777778   65.925926  53.111111  64.703704
# Grass     421.142857  67.271429   73.214286   70.800000  77.500000  70.428571
# ...

# %%
df[['Type 1','Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].groupby(['Type 1']).sum()
# Out:
#           Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Type 1
# Bug       26146  3925    4897     4880     3717     4471   4256
# Dark      13818  2071    2740     2177     2314     2155   2361
# Dragon    17617  2666    3588     2764     3099     2843   2657
# Electric  19510  2631    3040     2917     3961     3243   3718
# Fairy      7024  1260    1046     1117     1335     1440    826
# Fighting  11244  1886    2613     1780     1434     1747   1784
# Fire      23820  3635    4408     3524     4627     3755   3871
# Flying     1940   283     315      265      377      290    410
# Ghost     14066  2062    2361     2598     2539     2447   2059
# Grass     29480  4709    5125     4956     5425     4930   4335
# Ground    14000  2361    3064     2715     1807     2008   2045
# Ice       10403  1728    1746     1714     1861     1831   1523
# Normal    39365  7573    7200     5865     5470     6245   7012
# Poison    11176  1883    2091     1927     1692     1803   1780
# ...

# %%
df[['Type 1','Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].groupby(['Type 1']).count()
# Out:
#           Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Type 1
# Bug          69   69      69       69       69       69     69
# Dark         31   31      31       31       31       31     31
# Dragon       32   32      32       32       32       32     32
# Electric     44   44      44       44       44       44     44
# Fairy        17   17      17       17       17       17     17
# Fighting     27   27      27       27       27       27     27
# Fire         52   52      52       52       52       52     52
# Flying        4    4       4        4        4        4      4
# Ghost        32   32      32       32       32       32     32
# Grass        70   70      70       70       70       70     70
# Ground       32   32      32       32       32       32     32
# Ice          24   24      24       24       24       24     24
# Normal       98   98      98       98       98       98     98
# Poison       28   28      28       28       28       28     28
# ...

# %%
df2 = df[['Type 1','Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]

# %%
df2.head()
# Out:
#   Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0  Grass    318  45      49       49       65       65     45
# 1  Grass    405  60      62       63       80       80     60
# 2  Grass    525  80      82       83      100      100     80
# 3  Grass    625  80     100      123      122      120     80
# 4   Fire    309  39      52       43       60       50     65

# %%
df2.groupby(['Type 1']).count()
# Out:
#           Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Type 1
# Bug          69   69      69       69       69       69     69
# Dark         31   31      31       31       31       31     31
# Dragon       32   32      32       32       32       32     32
# Electric     44   44      44       44       44       44     44
# Fairy        17   17      17       17       17       17     17
# Fighting     27   27      27       27       27       27     27
# Fire         52   52      52       52       52       52     52
# Flying        4    4       4        4        4        4      4
# Ghost        32   32      32       32       32       32     32
# Grass        70   70      70       70       70       70     70
# Ground       32   32      32       32       32       32     32
# Ice          24   24      24       24       24       24     24
# Normal       98   98      98       98       98       98     98
# Poison       28   28      28       28       28       28     28
# ...

# %%
df = pd.read_csv('modified.csv')

df['count'] = 1

df.groupby(['Type 1']).count()['count']

#df2.groupby(['Type 1']).count()
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df = pd.read_csv('modified.csv')

df['count'] = 1

df.groupby(['Type 1','Type 2']).count()['count']

#df2.groupby(['Type 1']).count()
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
